# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('insurance_dataset.csv')
df.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46    male  21.45         5    yes  southeast        Diabetes
# 1   25  female  25.38         2    yes  northwest        Diabetes
# 2   38    male  44.88         2    yes  southwest             NaN
# 3   25    male  19.89         0     no  northwest             NaN
# 4   49    male  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history exercise_frequency    occupation coverage_level  \
# 0                    NaN              Never   Blue collar        Premium
# 1    High blood pressure       Occasionally  White collar        Premium
# 2    High blood pressure       Occasionally   Blue collar        Premium
# 3               Diabetes             Rarely  White collar       Standard
# 4    High blood pressure             Rarely  White collar       Standard
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %%
df.describe()
# Out:
#                   age             bmi        children         charges
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        41.495282       34.001839        2.499886    16735.117481
# std         13.855189        9.231680        1.707679     4415.808211
# min         18.000000       18.000000        0.000000     3445.011643
# 25%         29.000000       26.020000        1.000000    13600.372379
# 50%         41.000000       34.000000        2.000000    16622.127973
# 75%         53.000000       41.990000        4.000000    19781.465410
# max         65.000000       50.000000        5.000000    32561.560374

# %%
df["coverage_level"].unique()
# Out:
# array(['Premium', 'Standard', 'Basic'], dtype=object)

# %%
df["coverage_level"].replace({"Basic": 0, "Standard": 1, "Premium": 2}, inplace=True)

# %% [markdown]
# We replace the coverage levels with integers representative of the different tiers

# %%
df.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46    male  21.45         5    yes  southeast        Diabetes
# 1   25  female  25.38         2    yes  northwest        Diabetes
# 2   38    male  44.88         2    yes  southwest             NaN
# 3   25    male  19.89         0     no  northwest             NaN
# 4   49    male  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history exercise_frequency    occupation  coverage_level  \
# 0                    NaN              Never   Blue collar               2
# 1    High blood pressure       Occasionally  White collar               2
# 2    High blood pressure       Occasionally   Blue collar               2
# 3               Diabetes             Rarely  White collar               1
# 4    High blood pressure             Rarely  White collar               1
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %%
df["exercise_frequency"].unique()
# Out:
# array(['Never', 'Occasionally', 'Rarely', 'Frequently'], dtype=object)

# %%
df["exercise_frequency"].replace({'Never': 0, 'Rarely': 1, 'Occasionally': 2, 'Frequently': 3}, inplace=True)

# %% [markdown]
# We do the same with the exercise frequency

# %%
df.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46    male  21.45         5    yes  southeast        Diabetes
# 1   25  female  25.38         2    yes  northwest        Diabetes
# 2   38    male  44.88         2    yes  southwest             NaN
# 3   25    male  19.89         0     no  northwest             NaN
# 4   49    male  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history  exercise_frequency    occupation  coverage_level  \
# 0                    NaN                   0   Blue collar               2
# 1    High blood pressure                   2  White collar               2
# 2    High blood pressure                   2   Blue collar               2
# 3               Diabetes                   1  White collar               1
# 4    High blood pressure                   1  White collar               1
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %%
print(df["coverage_level"].corr(df["charges"]))
# Out:
# 0.46298126452652066

# %%
df["gender"].replace({"male": 0, "female": 1}, inplace=True)
df.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46       0  21.45         5    yes  southeast        Diabetes
# 1   25       1  25.38         2    yes  northwest        Diabetes
# 2   38       0  44.88         2    yes  southwest             NaN
# 3   25       0  19.89         0     no  northwest             NaN
# 4   49       0  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history  exercise_frequency    occupation  coverage_level  \
# 0                    NaN                   0   Blue collar               2
# 1    High blood pressure                   2  White collar               2
# 2    High blood pressure                   2   Blue collar               2
# 3               Diabetes                   1  White collar               1
# 4    High blood pressure                   1  White collar               1
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %%
df["smoker"].replace({"no": 0, "yes": 1}, inplace=True)
df.head()
# Out:
#    age  gender    bmi  children  smoker     region medical_history  \
# 0   46       0  21.45         5       1  southeast        Diabetes
# 1   25       1  25.38         2       1  northwest        Diabetes
# 2   38       0  44.88         2       1  southwest             NaN
# 3   25       0  19.89         0       0  northwest             NaN
# 4   49       0  38.21         3       1  northwest        Diabetes
#
#   family_medical_history  exercise_frequency    occupation  coverage_level  \
# 0                    NaN                   0   Blue collar               2
# 1    High blood pressure                   2  White collar               2
# 2    High blood pressure                   2   Blue collar               2
# 3               Diabetes                   1  White collar               1
# 4    High blood pressure                   1  White collar               1
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %% [markdown]
# Currently our qualitative rows left are region, medial history, family medical history, and occupation

# %%
df.describe()
# Out:
#                   age          gender             bmi        children  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        41.495282        0.499893       34.001839        2.499886
# std         13.855189        0.500000        9.231680        1.707679
# min         18.000000        0.000000       18.000000        0.000000
# 25%         29.000000        0.000000       26.020000        1.000000
# 50%         41.000000        0.000000       34.000000        2.000000
# 75%         53.000000        1.000000       41.990000        4.000000
# max         65.000000        1.000000       50.000000        5.000000
#
#                smoker  exercise_frequency  coverage_level         charges
# count  1000000.000000      1000000.000000  1000000.000000  1000000.000000
# mean         0.500129            1.500500        0.999462    16735.117481
# std          0.500000            1.117229        0.816390     4415.808211
# min          0.000000            0.000000        0.000000     3445.011643
# 25%          0.000000            1.000000        0.000000    13600.372379
# 50%          1.000000            2.000000        1.000000    16622.127973
# 75%          1.000000            2.000000        2.000000    19781.465410
# max          1.000000            3.000000        2.000000    32561.560374

# %% [markdown]
# There are no missing values for any of our current quantitative collums

# %% [markdown]
# ## Current observations
#
# - our dataset has a slight male bias (however it does seem pretty even)
# - our dataset is fairly evenly distributed between smoker and non-smoker with more people smoking than not
# - the average age of the people in the dataset is around 41-42
# - most people have the standard level plan with the distribution of the plans being fairly even
# - the average person in out data set has 2-3 children

# %%
hist = df.hist(bins=15, figsize=(15,15))

# %% [markdown]
# Here we can see that visually

# %%
def analyze_cohorts(df, attribute, attribute_name, bins=None):
    if bins is not None:
        df[attribute] = pd.cut(df[attribute], bins)
        
    cohorts = df.groupby(attribute)
    for cohort, group_data in cohorts:
        average_charges = group_data['charges'].mean()
        print(f'{attribute_name}: {cohort}, Average Charges: {average_charges:.2f}')
    print()
    for cohort, group_data in cohorts:
        average_freq = group_data['exercise_frequency'].median()
        print(f'{attribute_name}: {cohort}, median exercise frequency: {average_freq}')
        average_freq = group_data['exercise_frequency'].mean()
        print(f'{attribute_name}: {cohort}, mean exercise frequency: {average_freq}')

# Define cohort analyses
cohort_analyses = [
    ('age', 'Age', [0, 20, 30, 40, 50, 60, float('inf')]),
    ('gender', 'Gender', None),
    ('exercise_frequency', 'Exercise Frequency', None),
    ('region', 'Region', None),
    ('smoker', 'Smoking Status', None),
    ('occupation', 'Occupation', None),
    ('bmi', 'BMI', [0, 20, 25, 30, 35, 40, float('inf')])
]

# Perform cohort analysis for each variable
for attribute, attribute_name, bins in cohort_analyses:
    print(f'--- {attribute_name} Cohort Analysis ---')
    analyze_cohorts(df.copy(), attribute, attribute_name, bins)
    print()
# Out:
# --- Age Cohort Analysis ---
# /var/folders/yk/gbf3m60d1_bgv0fsygnh_15r0000gn/T/ipykernel_70269/2836982737.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cohorts = df.groupby(attribute)
# Age: (0.0, 20.0], Average Charges: 16275.22
# Age: (20.0, 30.0], Average Charges: 16418.26
# Age: (30.0, 40.0], Average Charges: 16612.20
# Age: (40.0, 50.0], Average Charges: 16804.92
# Age: (50.0, 60.0], Average Charges: 17027.43
# Age: (60.0, inf], Average Charges: 17167.83
#
# Age: (0.0, 20.0], median exercise frequency: 1.0
# Age: (0.0, 20.0], mean exercise frequency: 1.5009642202565943
# Age: (20.0, 30.0], median exercise frequency: 2.0
# Age: (20.0, 30.0], mean exercise frequency: 1.5028297946898748
# Age: (30.0, 40.0], median exercise frequency: 1.0
# Age: (30.0, 40.0], mean exercise frequency: 1.49645083725685
# Age: (40.0, 50.0], median exercise frequency: 2.0
# Age: (40.0, 50.0], mean exercise frequency: 1.5035437154271665
# Age: (50.0, 60.0], median exercise frequency: 1.0
# Age: (50.0, 60.0], mean exercise frequency: 1.4989689234984498
# Age: (60.0, inf], median exercise frequency: 2.0
# Age: (60.0, inf], mean exercise frequency: 1.5006328749784248
#
# --- Gender Cohort Analysis ---
# Gender: 0, Average Charges: 17236.32
# Gender: 1, Average Charges: 16233.70
#
# Gender: 0, median exercise frequency: 2.0
# Gender: 0, mean exercise frequency: 1.5002309505765765
# Gender: 1, median exercise frequency: 2.0
# Gender: 1, mean exercise frequency: 1.5007691646012247
#
# --- Exercise Frequency Cohort Analysis ---
# Exercise Frequency: 0, Average Charges: 15865.63
# Exercise Frequency: 1, Average Charges: 16347.35
# Exercise Frequency: 2, Average Charges: 16869.08
# Exercise Frequency: 3, Average Charges: 17857.94
#
# Exercise Frequency: 0, median exercise frequency: 0.0
# Exercise Frequency: 0, mean exercise frequency: 0.0
# Exercise Frequency: 1, median exercise frequency: 1.0
# Exercise Frequency: 1, mean exercise frequency: 1.0
# Exercise Frequency: 2, median exercise frequency: 2.0
# Exercise Frequency: 2, mean exercise frequency: 2.0
# Exercise Frequency: 3, median exercise frequency: 3.0
# Exercise Frequency: 3, mean exercise frequency: 3.0
#
# --- Region Cohort Analysis ---
# Region: northeast, Average Charges: 17235.92
# Region: northwest, Average Charges: 16528.66
# Region: southeast, Average Charges: 16738.55
# Region: southwest, Average Charges: 16436.72
#
# Region: northeast, median exercise frequency: 2.0
# Region: northeast, mean exercise frequency: 1.5035051908781152
# Region: northwest, median exercise frequency: 2.0
# Region: northwest, mean exercise frequency: 1.5014624036234
# Region: southeast, median exercise frequency: 1.0
# Region: southeast, mean exercise frequency: 1.4971698226582435
# Region: southwest, median exercise frequency: 1.0
# Region: southwest, mean exercise frequency: 1.4998540554589257
#
# --- Smoking Status Cohort Analysis ---
# Smoking Status: 0, Average Charges: 14234.19
# Smoking Status: 1, Average Charges: 19234.76
#
# Smoking Status: 0, median exercise frequency: 1.0
# Smoking Status: 0, mean exercise frequency: 1.500363093678169
# Smoking Status: 1, median exercise frequency: 2.0
# Smoking Status: 1, mean exercise frequency: 1.5006368356963904
#
# --- Occupation Cohort Analysis ---
# Occupation: Blue collar, Average Charges: 17233.48
# Occupation: Student, Average Charges: 16236.86
# Occupation: Unemployed, Average Charges: 15741.31
# Occupation: White collar, Average Charges: 17734.69
#
# Occupation: Blue collar, median exercise frequency: 1.0
# Occupation: Blue collar, mean exercise frequency: 1.4981366956869808
# Occupation: Student, median exercise frequency: 1.0
# Occupation: Student, mean exercise frequency: 1.4997582697709357
# Occupation: Unemployed, median exercise frequency: 2.0
# Occupation: Unemployed, mean exercise frequency: 1.5012631150452367
# Occupation: White collar, median exercise frequency: 2.0
# Occupation: White collar, mean exercise frequency: 1.5028456833450317
#
# --- BMI Cohort Analysis ---
# BMI: (0.0, 20.0], Average Charges: 15983.54
# BMI: (20.0, 25.0], Average Charges: 16165.66
# BMI: (25.0, 30.0], Average Charges: 16418.97
# BMI: (30.0, 35.0], Average Charges: 16643.67
# BMI: (35.0, 40.0], Average Charges: 16904.93
# BMI: (40.0, inf], Average Charges: 17289.23
#
# BMI: (0.0, 20.0], median exercise frequency: 1.0
# BMI: (0.0, 20.0], mean exercise frequency: 1.4952549846625767
# BMI: (20.0, 25.0], median exercise frequency: 2.0
# BMI: (20.0, 25.0], mean exercise frequency: 1.5025976611416865
# BMI: (25.0, 30.0], median exercise frequency: 1.0
# BMI: (25.0, 30.0], mean exercise frequency: 1.5005429089701336
# BMI: (30.0, 35.0], median exercise frequency: 2.0
# BMI: (30.0, 35.0], mean exercise frequency: 1.5012776287210936
# BMI: (35.0, 40.0], median exercise frequency: 2.0
# BMI: (35.0, 40.0], mean exercise frequency: 1.5042731218399032
# BMI: (40.0, inf], median exercise frequency: 1.0
# BMI: (40.0, inf], mean exercise frequency: 1.4982027525757342
# /var/folders/yk/gbf3m60d1_bgv0fsygnh_15r0000gn/T/ipykernel_70269/2836982737.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cohorts = df.groupby(attribute)

# %%
mental = pd.read_csv('survey.csv')
mental.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]
