# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('vehicle_insurance_claims.csv')
data.sort_values(by=['incident_state','incident_city'])
df = data.copy()
cohorts = df.groupby(by=['incident_state'])
for cohort, group_data in cohorts:
    count = group_data['incident_city'].value_counts()
    print(f'{cohort}') 
    print(f'Incident city: {count}')
prepData = pd.read_csv('Crashes_With_Pop.csv')
prepData['Land Area-sq mi'].replace({'N/A': None},inplace=True)
prepData.corr(method='pearson', numeric_only=True)
# Out:
# ('NC',)
# Incident city: incident_city
# Arlington      25
# Riverwood      20
# Springfield    15
# Hillsdale      14
# Northbend      14
# Northbrook     12
# Columbus       10
# Name: count, dtype: int64
# ('NY',)
# Incident city: incident_city
# Columbus       47
# Springfield    43
# Arlington      39
# Northbend      34
# Riverwood      34
# Hillsdale      34
# Northbrook     31
# Name: count, dtype: int64
# ('OH',)
# Incident city: incident_city
# Arlington      5
# Springfield    5
# Northbrook     3
# Hillsdale      3
# Columbus       3
# Riverwood      2
# Northbend      2
# Name: count, dtype: int64
# ('PA',)
# Incident city: incident_city
# Hillsdale      6
# Northbrook     5
# Springfield    5
# Northbend      5
# Columbus       4
# Riverwood      4
# Arlington      1
# Name: count, dtype: int64
# ('SC',)
# Incident city: incident_city
# Columbus       39
# Arlington      38
# Springfield    38
# Northbend      38
# Hillsdale      33
# Riverwood      33
# ...
